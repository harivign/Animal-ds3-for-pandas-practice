# %% [markdown]
# <a href="https://colab.research.google.com/github/harivign/Animal-ds3-for-pandas-practice/blob/main/animal_dataset3_practice_using_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #pandas practices

# %%
#Find the top 5 animal species with the longest average lifespan.
#How many species belong to each diet type (Herbivore, Carnivore, Omnivore)?
#List all the species that are currently listed as "Endangered".
#What is the maximum and minimum lifespan for each diet type (Herbivore, Carnivore, Omnivore)?

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Animal Dataset.csv")

# %%
df
# Out:
#                   Animal Height (cm) Weight (kg)             Color  \
# 0               Aardvark     105-130       40-65              Grey
# 1               Aardwolf       40-50      Aug-14      Yellow-brown
# 2       African Elephant     270-310   2700-6000              Grey
# 3           African Lion      80-110     120-250               Tan
# 4       African Wild Dog       75-80       18-36      Multicolored
# ..                   ...         ...         ...               ...
# 200                  Yak     140-160    500-1200      Brown, Black
# 201  Yellow-Eyed Penguin       60-65      01-Mar     Yellow, White
# 202            Yeti Crab    Up to 15   Up to 0.5      White, Hairy
# 203                Zebra     220-340     400-900      Black, White
# 204          Zebra Shark   Up to 330    Up to 32  Brown, Yellowish
#
#     Lifespan (years)         Diet               Habitat  \
# 0              20-30  Insectivore  Savannas, Grasslands
# ...

# %%
#Find the top 5 animal species with the longest average lifespan.

# %%
top5_lifespan=df.sort_values("Lifespan (years)",ascending=False).head(5)
top5_lifespan
# Out:
#              Animal Height (cm)  Weight (kg)          Color Lifespan (years)  \
# 69      Galliformes      Varies       Varies         Varies           Varies
# 118  Monitor Lizard   Up to 244    Up to 166         Varies           Varies
# 184         Vulture      Varies       Varies   Black, Brown           Varies
# 170         Termite   Up to 0.5   Up to 0.02         Varies           Varies
# 199  Woolly Mammoth  Up to 4200  Up to 12000  Brown, Shaggy           Varies
#
#           Diet              Habitat       Predators Average Speed (km/h)  \
# 69    Omnivore               Varies          Varies               Varies
# 118  Carnivore              Various   Birds, Snakes               Varies
# 184  Carnivore              Various  Not Applicable               Varies
# 170  Herbivore  Forests, Grasslands  Not Applicable               Varies
# 199  Herbivore               Tundra  Not Applicable               Varies
#
# ...

# %%
print(top5_lifespan[["Animal","Lifespan (years)"]])
# Out:
#              Animal Lifespan (years)
# 69      Galliformes           Varies
# 118  Monitor Lizard           Varies
# 184         Vulture           Varies
# 170         Termite           Varies
# 199  Woolly Mammoth           Varies

# %%
#How many species belong to each diet type (Herbivore, Carnivore, Omnivore)?

# %%
df
# Out:
#                          Animal     Height (cm)     Weight (kg)  \
# 0                      Aardvark         105-130           40-65
# 1                      Aardwolf           40-50          Aug-14
# 2              African Elephant         270-310       2700-6000
# 3                  African Lion          80-110         120-250
# 4              African Wild Dog           75-80           18-36
# 5                   Alpine Ibex          67-101          19-120
# 6        Amazon Rainforest Frog          Feb-13       Up to 0.5
# 7                American Bison         152-186       318-1,000
# 8                      Anteater           52-91           22-41
# 9                 Arabian Horse         140-160        380-1000
# 10                 Arabian Oryx           70-90           65-90
# 11                   Arctic Fox           25-30           2.5-9
# 12                      Arowana       Up to 120       Up to 6.7
# 13               Asian Elephant         200-300       2000-5000
# ...

# %%
df["Diet"].unique()
# Out:
# array(['Insectivore', 'Herbivore', 'Carnivore', 'Omnivore',
#        'Carnivore, Piscivore', 'Omnivore, Insectivore',
#        'Herbivore, Omnivore', 'Filter Feeder', 'Piscivore',
#        'Insectivore, Herbivore', 'Scavenger', 'Carnivore, Scavenger',
#        'Nectar, Insects', 'Carnivore, Insectivore', 'Omnivore, Herbivore',
#        'Herbivore, Insectivore'], dtype=object)

# %%
pd.set_option("display.max_rows",None)

# %%
diets=df.groupby("Animal")["Diet"].count()
diets
# Out:
# Animal
# Aardvark                      1
# Aardwolf                      1
# African Elephant              1
# African Lion                  1
# African Wild Dog              1
# Alpine Ibex                   1
# Amazon Rainforest Frog        1
# American Bison                1
# Anteater                      1
# Arabian Horse                 1
# Arabian Oryx                  1
# Arctic Fox                    1
# Arowana                       1
# Asian Elephant                1
# Atlantic Puffin               1
# Atlantic Spotted Dolphin      1
# Australian Fur Seal           1
# Axolotl                       1
# Aye-Aye                       1
# Baird's Tapir                 1
# Bald Eagle                    1
# Banded Palm Civet             1
# Barbary Macaque               1
# Basking Shark                 1
# Bearded Dragon                1
# Bengal Fox                    1
# Bengal Tiger                  1
# Black Rhinoceros              1
# Blobfish                      2
# ...

# %%
diets=df.groupby("Animal")["Diet"].value_counts()
diets
# Out:
# Animal                      Diet
# Aardvark                    Insectivore               1
# Aardwolf                    Insectivore               1
# African Elephant            Herbivore                 1
# African Lion                Carnivore                 1
# African Wild Dog            Carnivore                 1
# Alpine Ibex                 Herbivore                 1
# Amazon Rainforest Frog      Insectivore               1
# American Bison              Herbivore                 1
# Anteater                    Insectivore               1
# Arabian Horse               Herbivore                 1
# Arabian Oryx                Herbivore                 1
# Arctic Fox                  Omnivore                  1
# Arowana                     Carnivore, Piscivore      1
# Asian Elephant              Herbivore                 1
# Atlantic Puffin             Carnivore, Piscivore      1
# Atlantic Spotted Dolphin    Carnivore                 1
# ...

# %%
#answer in unique

# %%
herbivore_count = df[df['Diet'] == 'Herbivore'].shape[0]
carnivore_count = df[df['Diet'] == 'Carnivore'].shape[0]
omnivore_count = df[df['Diet'] == 'Omnivore'].shape[0]

# %%
print(f"Herbivore Count: {herbivore_count}")
print(f"Carnivore Count: {carnivore_count}")
print(f"Omnivore Count: {omnivore_count}")
# Out:
# Herbivore Count: 54
# Carnivore Count: 72
# Omnivore Count: 40

# %%
#List all the species that are currently listed as "Endangered".

# %%
df
# Out:
#                          Animal     Height (cm)     Weight (kg)  \
# 0                      Aardvark         105-130           40-65
# 1                      Aardwolf           40-50          Aug-14
# 2              African Elephant         270-310       2700-6000
# 3                  African Lion          80-110         120-250
# 4              African Wild Dog           75-80           18-36
# 5                   Alpine Ibex          67-101          19-120
# 6        Amazon Rainforest Frog          Feb-13       Up to 0.5
# 7                American Bison         152-186       318-1,000
# 8                      Anteater           52-91           22-41
# 9                 Arabian Horse         140-160        380-1000
# 10                 Arabian Oryx           70-90           65-90
# 11                   Arctic Fox           25-30           2.5-9
# 12                      Arowana       Up to 120       Up to 6.7
# 13               Asian Elephant         200-300       2000-5000
# ...

# %%
endangered=df[df["Conservation Status"]=="Endangered"]
print(endangered[["Animal","Conservation Status"]])
# Out:
#                   Animal Conservation Status
# 4       African Wild Dog          Endangered
# 13        Asian Elephant          Endangered
# 18               Aye-Aye          Endangered
# 19         Baird's Tapir          Endangered
# 22       Barbary Macaque          Endangered
# 26          Bengal Tiger          Endangered
# 32            Blue Whale          Endangered
# 35                Bonobo          Endangered
# 44            Chimpanzee          Endangered
# 50     Coquerel's Sifaka          Endangered
# 52                 Dhole          Endangered
# 55       Eastern Gorilla          Endangered
# 66    GalÃ¡pagos Penguin          Endangered
# 67     Galápagos Penguin          Endangered
# 74           Giant Panda          Endangered
# 79   Golden Lion Tamarin          Endangered
# 84      Green Sea Turtle          Endangered
# 85      Green Sea Turtle          Endangered
# 86         Grevy's Zebra          Endangered
# 95          Iberian Lynx          Endangered
# ...

# %%
df.to_csv("animal_dataset.csv",index=False)

# %%
#What is the maximum and minimum lifespan for each diet type (Herbivore, Carnivore, Omnivore)?

# %%
max=df.groupby("Diet")["Lifespan (years)"].max()
max
# Out:
# Diet
# Carnivore                         Varies
# Carnivore, Insectivore         Up to 100
# Carnivore, Piscivore              Oct-20
# Carnivore, Scavenger      Up to 20 years
# Filter Feeder                      70-90
# Herbivore                         Varies
# Herbivore, Insectivore          Up to 32
# Herbivore, Omnivore             Up to 30
# Insectivore                       Varies
# Insectivore, Herbivore            Oct-15
# Nectar, Insects                   03-May
# Omnivore                          Varies
# Omnivore, Herbivore                20-30
# Omnivore, Insectivore             Dec-14
# Piscivore                         Dec-17
# Scavenger                      Up to 300
# Name: Lifespan (years), dtype: object

# %%
min=df.groupby("Diet")["Lifespan (years)"].min()
min
# Out:
# Diet
# Carnivore                    01-Feb
# Carnivore, Insectivore       03-Jun
# Carnivore, Piscivore          15-20
# Carnivore, Scavenger         05-Aug
# Filter Feeder                70-100
# Herbivore                    02-May
# Herbivore, Insectivore     Up to 32
# Herbivore, Omnivore        Up to 30
# Insectivore                  04-Aug
# Insectivore, Herbivore       Oct-15
# Nectar, Insects              03-May
# Omnivore                     02-May
# Omnivore, Herbivore           20-30
# Omnivore, Insectivore         20-23
# Piscivore                    Dec-17
# Scavenger                 Up to 300
# Name: Lifespan (years), dtype: object
